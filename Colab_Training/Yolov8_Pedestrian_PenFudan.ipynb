# %%
# connect google drive and google colab
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/MAK1647/Yolov8_2562023.git
# Out:
# Cloning into 'Yolov8_2562023'...
# remote: Enumerating objects: 474, done.
# remote: Counting objects: 100% (474/474), done.
# remote: Compressing objects: 100% (422/422), done.
# remote: Total 474 (delta 42), reused 441 (delta 31), pack-reused 0
# Receiving objects: 100% (474/474), 804.44 KiB | 23.66 MiB/s, done.
# Resolving deltas: 100% (42/42), done.

# %%
# %cd /content/Yolov8_2562023/ultralytics-main/ultralytics-main
# !pip install -r requirements.txt
# Out:
# /content/Yolov8_2562023/ultralytics-main/ultralytics-main
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# %cd /content/Yolov8_2562023/ultralytics-main/ultralytics-main
# !python main.py
# Out:
# /content/Yolov8_2562023/ultralytics-main/ultralytics-main
# Ultralytics YOLOv8.0.122 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
