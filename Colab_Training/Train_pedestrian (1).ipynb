# %%
# connect google drive and google colab
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#Download Yolov5 sandbox to respository
# !git clone -b v7.0 https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16117, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 16117 (delta 9), reused 11 (delta 1), pack-reused 16089
# Receiving objects: 100% (16117/16117), 14.80 MiB | 22.82 MiB/s, done.
# Resolving deltas: 100% (11033/11033), done.
# Note: switching to '915bbf294bb74c859f0b41f1c23bc395014ea679'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false

# %%
#Install requirement for Yolov5
# !git clone -b v6.2 https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15705, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 15705 (delta 10), reused 17 (delta 6), pack-reused 15672
# Receiving objects: 100% (15705/15705), 14.50 MiB | 31.13 MiB/s, done.
# Resolving deltas: 100% (10755/10755), done.
# Note: switching to 'd3ea0df8b9f923685ce5f2555c303b8eddbf83fd'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15637, done.
# remote: Counting objects: 100% (244/244), done.
# remote: Compressing objects: 100% (147/147), done.
# remote: Total 15637 (delta 123), reused 167 (delta 97), pack-reused 15393
# Receiving objects: 100% (15637/15637), 14.64 MiB | 29.93 MiB/s, done.
# Resolving deltas: 100% (10651/10651), done.

# %%
#Install requirement for Yolov5
# !pip install  -r /content/yolov5/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 13.6 MB/s eta 0:00:00
# ...

# %%
# Start Training
# %cd /content/yolov5
# !python train.py --img 640 --batch 16 --epochs 2 --data data1.yaml --cfg /content/yolov5/models/yolov5s.yaml --project /content/gdrive/MyDrive/Train_Yolov5/kq/PenFudan --weights yolov5s.pt
# Out:
# /content/yolov5
# 2023-12-31 13:03:09.326299: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-31 13:03:09.326346: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-31 13:03:09.327621: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-31 13:03:10.346271: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
# %cd /content/yolov5
# !python train.py --img 640 --batch 16 --epochs 2 --data /content/gdrive/MyDrive/data1.yaml --cfg /content/yolov5/models/yolov5s.yaml  --weights yolov5s.pt
# Out:
# /content/yolov5
# 2023-08-19 10:51:46.994591: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-19 10:51:47.852355: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
# Deploy module for images
# !python /content/yolov5/detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt  --conf 0.4 --iou 0.45 --source /content/gdrive/MyDrive/Train_Yolov5/kq/Russia_1_2_3
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/gdrive/MyDrive/Train_Yolov5/kq/Russia_1_2_3, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-0-g915bbf2 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/8 /content/gdrive/MyDrive/Train_Yolov5/kq/Russia_1_2_3/japan_1.png: 256x640 (no detections), 68.4ms
# image 2/8 /content/gdrive/MyDrive/Train_Yolov5/kq/Russia_1_2_3/japan_2.png: 256x640 (no detections), 6.3ms
# ...
